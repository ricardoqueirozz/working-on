# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_16/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data1 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data1.drop(i,inplace = True, axis=1)
data1.rename(columns={4:"SINR"}, inplace = True)

#print(data1)

opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_17/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data2 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data2.drop(i,inplace = True, axis=1)
data2.rename(columns={4:"SINR"}, inplace = True)

#print(data2)

opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_18/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data3 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data3.drop(i,inplace = True, axis=1)
data3.rename(columns={4:"SINR"}, inplace = True)

#print(data3)

opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_19/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data4 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data4.drop(i,inplace = True, axis=1)
data4.rename(columns={4:"SINR"}, inplace = True)

#print(data4)

opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_20/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data5 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data5.drop(i,inplace = True, axis=1)
data5.rename(columns={4:"SINR"}, inplace = True)

#print(data5)

opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_21/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data6 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data6.drop(i,inplace = True, axis=1)
data6.rename(columns={4:"SINR"}, inplace = True)

#print(data6)

opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_22/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data7 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data7.drop(i,inplace = True, axis=1)
data7.rename(columns={4:"SINR"}, inplace = True)

#print(data7)

opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/" 
# %cd $opath
opath = "/home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_23/" 
# %cd $opath

data = pd.read_csv('nr-rem-.out', sep="\t", header=None)
data8 = pd.DataFrame(data)
for i in range(0,7):
    if i != 4:
        data8.drop(i,inplace = True, axis=1)
data8.rename(columns={4:"SINR"}, inplace = True)

#print(data4)
# Out:
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_16
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_17
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_18
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_19
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_20
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_21
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_22
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0
# /home/ricardo/Repositories/working-on/rem-artigo/JOB0/Sim_23

# %%
temp=0
bg = 0
temp=[data1.SINR < 0.960405542954275]
for i in range(len(data1)):
    if (temp[0][i]):
        bg+=1
        #data1.drop(i,inplace=True,axis=0)
temp=0
bg2 = 0
temp=[data2.SINR < 0.960405542954275]
for i in range(len(data2)):
    if (temp[0][i]):
        bg2+=1
        #data2.drop(i,inplace=True,axis=0)
temp=0
bg3 = 0
temp=[data3.SINR < 0.960405542954275]
for i in range(len(data3)):
    if (temp[0][i]):
        bg3+=1
        #data3.drop(i,inplace=True,axis=0)
temp=0
bg4 = 0
temp=[data4.SINR < 0.960405542954275]
for i in range(len(data4)):
    if (temp[0][i]):
        bg4+=1
        #data4.drop(i,inplace=True,axis=0)
temp=0
bg5 = 0
temp=[data5.SINR < 0.960405542954275]
for i in range(len(data5)):
    if (temp[0][i]):
        bg5+=1
        #data1.drop(i,inplace=True,axis=0)
temp=0
bg6 = 0
temp=[data6.SINR < 0.960405542954275]
for i in range(len(data6)):
    if (temp[0][i]):
        bg6+=1
        #data2.drop(i,inplace=True,axis=0)
temp=0
bg7 = 0
temp=[data7.SINR < 0.960405542954275]
for i in range(len(data7)):
    if (temp[0][i]):
        bg7+=1
        #data3.drop(i,inplace=True,axis=0)
temp=0
bg8 = 0
temp=[data8.SINR < 0.960405542954275]
for i in range(len(data8)):
    if (temp[0][i]):
        bg8+=1
        #data4.drop(i,inplace=True,axis=0)
      
result1 = (bg/(len(data1)))*100
result2 = (bg2/(len(data2)))*100
result3 = (bg3/(len(data3)))*100
result4 = (bg4/(len(data4)))*100
result5 = (bg5/(len(data5)))*100
result6 = (bg6/(len(data6)))*100
result7 = (bg7/(len(data7)))*100
result8 = (bg8/(len(data8)))*100

print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
print(result6)
print(result7)
print(result8)
# Out:
# 0.0
# 2.5642635196635384
# 29.57848152914221
# 56.06540912086877
# 2.705502024418568
# 23.411066821505916
# 43.592479834280155
# 62.8354414487932

# %%
graphx = ["1 Omnidirecional","2 Omnidirecionais","3 Omnidirecionais","4 Omnidirecionais", "1 Trissetorizada","2 Trissetorizadas","3 Trissetorizadas","4 Trissetorizadas"]
graphy = [result1,result2,result3,result4,result5,result6,result7,result8]

plt.figure(figsize=(25, 6))
plt.rcParams.update({'font.size': 15})
plt.title("Taxa de Outage", fontsize=20)
plt.xlabel("Tipo e Posicionamento das Antenas", fontsize=20)
plt.ylabel("Porcentagem", fontsize=20)
plt.ylim([0, 70])

plt.bar(graphx,graphy, color = "maroon", width = 0.8)
# Out:
# <BarContainer object of 8 artists>
