# %% [markdown]
# # SimPerScript Campaing
#
# ### Authors : Daniel (UFRN), Vicente Sousa (UFRN)

# %% [markdown]
# ## Directory where the files are located

# %%
path = "/home/ricardo/Repositories/working-on/ScriptsCampaign/" 
# %cd $path
# Out:
# /home/daniel/Daniel/ScriptsCampaign

# %% [markdown]
# ## Creating Random Seed
# This code was created to run only once. Do **NOT** run again if you have already the file "ListOfRandomNumbers.pkl"

# %% [raw]
# # Creating 1e5 uniform random numbers to be used as seeds in ns-3 simulations;
# import random
# import pickle
#
# jobRunSeed = [random.randint(0,23*10**14) for p in range(0, 10000)]
# with open('ListOfRandomNumbers.pkl', 'wb') as f:
#     pickle.dump(jobRunSeed, f)

# %% [markdown]
# ## Simulation Campaings (creation)

# %%
# %%file NrMmtcSimPerScriptCampaign.py
import os
import argparse
import pickle
import numpy as np

# To install YAML: sudo apt-get install python3-yaml
import yaml

class Simulation:
    def __init__(self, configurations_file):
        #self.email_to = 'sicrano@gmail.com'            
        with open(configurations_file, 'r') as f:
            self.doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
        self.campaign_name = os.path.splitext(configurations_file)[0]
       
        # Simu parameters
        self.commandScript = ''
        for iscenarioParameters in self.doc['scenarioParameters'].items():
            commandraw= " --"+str(iscenarioParameters[0])+"="+str(iscenarioParameters[1][0])
            self.commandScript = self.commandScript + commandraw
        #print (self.commandScript)
    
        # ns-3 script configuration
        self.ns3_path = str(self.doc['ns3Parameters']['ns3_path'])
        self.ns3_path = os.getcwd() + '/' + self.ns3_path
        self.ns3_script = str(self.doc['ns3Parameters']['ns3_script'])
        self.filename = str(self.doc['ns3Parameters']['filename'])
        self.configurations_file = configurations_file       
        self.cluster_path = str(self.doc['ns3Parameters']['cluster_path'])
        self.simLocation = str(self.doc['ns3Parameters']['simLocation'])
        
        # Shell Script Parameters configuration
        self.nOfCurlines=self.doc['ShellScriptParameters']['nOfCurlines']
        self.SimTied = self.doc['ShellScriptParameters']['SimTied']
        self.nOfCurlinesTied = self.doc['ShellScriptParameters']['nOfCurlinesTied']
        self.daytime  = self.doc['ShellScriptParameters']['daytime']
        self.htime  = self.doc['ShellScriptParameters']['htime']
        self.ntasks = self.doc['ShellScriptParameters']['ntasks']
        self.cpusPerTask = self.doc['ShellScriptParameters']['cpusPerTask']
        self.numberOfJobsShellScript = int(self.doc['ShellScriptParameters']['numberOfJobsShellScript'])
        
         #Lines/curves
        self.campaignX = self.doc['campaignLines']['campaignX']
        self.campaignLines = self.doc['campaignLines']['campaignLines']
        self.nJobs = int(self.doc['campaignLines']['jobs'])
        
    def recursiveCommand(self,CurLine,scenarioParameters,vposition):
        command = (" --"+CurLine+"="+scenarioParameters[CurLine][vposition])
        return command
        
    
    def runCampaign(self,curCampaign):
        # Configure simulation file in accordance with campaign parameter
        numberOfJobsShellScript = self.numberOfJobsShellScript
        for iCallScripts in range (0,int(self.nJobs/numberOfJobsShellScript)):
            sh_name_main = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_AllJOBS'+str(iCallScripts) +".sh"
            print("Main Shell Script: " + sh_name_main)  
            with open(sh_name_main, "w") as f:
                f.write("#!/bin/bash\n")
                #f.write("cd "+ self.cluster_path +"\n")
                for iJob in range(iCallScripts*numberOfJobsShellScript,iCallScripts*numberOfJobsShellScript + numberOfJobsShellScript):
                    for iSim in range(0, int(self.ntasks)):
                        sh_name = "run_"+self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(iSim)
                        f.write("sbatch " + sh_name + ".sh\n")            
        for iJob in range(0,self.nJobs):         
            nOfCurlines=int(self.nOfCurlines[0]) # number of Campaign Lines in 1 simulation (max value = 3)
            SimTied = int(self.SimTied[0]) # whether or not the simulation parameters are tied (0 or 1)
            nOfCurlinesTied = int(self.nOfCurlinesTied[0]) # number of Campaign Lines tied (max value = nOfCurlines)
            with open('ListOfRandomNumbers.pkl', 'rb') as f:
                    jobRunSeed = pickle.load(f)
            count = 0
            """
            if SimTied == 0:
                minIterations=1
                for CampaignLines in self.doc['campaignLines']['campaignLines']:
                    CurlineIteration = len(self.doc['scenarioParameters'][CampaignLines])
                    totalCurlineIterations = minIterations*CurlineIteration
                    minIterations= totalCurlineIterations
                
                for varParam in self.doc['scenarioParameters'][curCampaign]:
                    tracker = [0]*nOfCurlines
                    for itotalCurlineIterations in range(totalCurlineIterations):
                        sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(count)
                        print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
                        with open('run_%s.sh' % sh_name, 'w') as f:                    
                            f.write('#!/bin/bash\n')
                            f.write('#SBATCH --ntasks=1\n')
                            f.write('#SBATCH --cpus-per-task='+self.cpusPerTask+'\n')
                            f.write('#SBATCH --time='+self.daytime+'-'+self.htime+':0 #especifica o tempo máximo de execução do job, dado no padrão dias-horas:minutos\n')
                            f.write('module load softwares/gsrc/2020_05\n')
                            outputDir = self.cluster_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
                            #f.write('rm -rf '+outputDir+"/JOB"+str(iJob)+' 2>/dev/null\n')
                            #for iJob in range(0, self.nJobs):
                            f.write('mkdir -p '+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +'\n')
                            f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
                            f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
                            f.write("cd '"+self.cluster_path+"'"+"\n")
                            command1 = (
                            'srun -N 1 -n 1' +
                            " ./waf --cwd='"+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +"'"
                            " --run '"+self.ns3_script+
                            " --RngRun="+str(jobRunSeed[iJob]))
                            command = ''
                            for iCampaignLines in range(len(self.doc['campaignLines']['campaignLines'])):
                                commandraw=self.recursiveCommand(self.doc['campaignLines']['campaignLines'][iCampaignLines], self.doc['scenarioParameters'],tracker[iCampaignLines])
                                command = command + commandraw
                                maxParamCurline = len(self.doc['scenarioParameters'][self.doc['campaignLines']['campaignLines'][iCampaignLines]])
                                print (command)
                                if iCampaignLines == 0 and tracker[iCampaignLines] < maxParamCurline:
                                    tracker[iCampaignLines] +=1
                                elif iCampaignLines == 0 and tracker[iCampaignLines] == maxParamCurline:
                                    tracker[iCampaignLines] = 0
                                
                                if iCampaignLines > 0:
                                    maxParamCurlinePrevious = len(self.doc['scenarioParameters'][self.doc['campaignLines']['campaignLines'][iCampaignLines-1]])
                                    if tracker[iCampaignLines-1] == maxParamCurlinePrevious:
                                        tracker[iCampaignLines] +=1
                                        tracker[iCampaignLines-1] =0
                            
                            command3 =(
                            " --outputDir='"+outputDir+"/JOB"+str(iJob)+"'"+
                            command+
                            " --"+curCampaign+"="+varParam+
                            "' > "+outputDir+"/JOB"+str(iJob)+'/Sim_' + str(count)+'.out 2>&1')
                            f.write(command1+self.commandScript+command3+'\n')
                            count = count + 1
            """
            if nOfCurlines == 1 and SimTied == 0:
                with open('ListOfRandomNumbers.pkl', 'rb') as f:
                    jobRunSeed = pickle.load(f)
                curline = self.campaignLines[0]
                count=0
                for i in range(len(self.doc['scenarioParameters'][curline])):
                    for varParam in self.doc['scenarioParameters'][curCampaign]:
                        sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(count)
                        print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
                        with open('run_%s.sh' % sh_name, 'w') as f:
                            f.write('#!/bin/bash\n')
                            f.write('#SBATCH --ntasks=1\n')
                            f.write('#SBATCH --cpus-per-task='+self.cpusPerTask+'\n')
                            f.write('#SBATCH --time='+self.daytime+'-'+self.htime+':0 #especifica o tempo máximo de execução do job, dado no padrão dias-horas:minutos\n')
                            f.write('module load softwares/gsrc/2020_05\n')
                            outputDir = self.cluster_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
                            #f.write('rm -rf '+outputDir+"/JOB"+str(iJob)+' 2>/dev/null\n')
                            #for iJob in range(0, self.nJobs):
                            f.write('mkdir -p '+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +'\n')
                            f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
                            f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
                            f.write("cd '"+self.cluster_path+"'"+"\n")
                            command1 = (
                            'srun -N 1 -n 1' +
                            " ./waf --cwd='"+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +"'"
                            " --run '"+self.ns3_script+
                            " --RngRun="+str(jobRunSeed[iJob]))
                            command3 =(
                            " --outputDir='"+outputDir+"/JOB"+str(iJob)+"'"+
                            " --"+curline+"="+self.doc['scenarioParameters'][curline][i]+
                            " --"+curCampaign+"="+varParam+
                            "' > "+outputDir+"/JOB"+str(iJob)+'/Sim_' + str(count)+'.out 2>&1')
                            f.write(command1+self.commandScript+command3+'\n')
                            count = count + 1
            if nOfCurlines == 2 and SimTied == 0:
                with open('ListOfRandomNumbers.pkl', 'rb') as f:
                    jobRunSeed = pickle.load(f)
                curline = self.campaignLines[0]
                curline1 = self.campaignLines[1]
                count=0
                for i in range(len(self.doc['scenarioParameters'][curline])):
                    for j in range(len(self.doc['scenarioParameters'][curline1])):
                        for varParam in self.doc['scenarioParameters'][curCampaign]:
                            sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(count)
                            print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
                            with open('run_%s.sh' % sh_name, 'w') as f:
                                f.write('#!/bin/bash\n')
                                f.write('#SBATCH --ntasks=1\n')
                                f.write('#SBATCH --cpus-per-task='+self.cpusPerTask+'\n')
                                f.write('#SBATCH --time='+self.daytime+'-'+self.htime+':0 #especifica o tempo máximo de execução do job, dado no padrão dias-horas:minutos\n')
                                f.write('module load softwares/gsrc/2020_05\n')
                                outputDir = self.cluster_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
                                #f.write('rm -rf '+outputDir+"/JOB"+str(iJob)+' 2>/dev/null\n')
                                #for iJob in range(0, self.nJobs):
                                f.write('mkdir -p '+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +'\n')
                                f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
                                f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
                                f.write("cd '"+self.cluster_path+"'"+"\n")
                                command1 = (
                                'srun -N 1 -n 1' +
                                " ./waf --cwd='"+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +"'"
                                " --run '"+self.ns3_script+
                                " --RngRun="+str(jobRunSeed[iJob]))
                                command3 =(
                                " --outputDir='"+outputDir+"/JOB"+str(iJob)+"'"+
                                " --"+curline+"="+self.doc['scenarioParameters'][curline][i]+
                                " --"+curline1+"="+self.doc['scenarioParameters'][curline1][j]+
                                " --"+curCampaign+"="+varParam+
                                "' > "+outputDir+"/JOB"+str(iJob)+'/Sim_' + str(count)+'.out 2>&1')
                                f.write(command1+self.commandScript+command3+'\n')
                                count = count + 1
            
            if nOfCurlines == 3 and SimTied == 0:
                with open('ListOfRandomNumbers.pkl', 'rb') as f:
                    jobRunSeed = pickle.load(f)
                curline = self.campaignLines[0]
                curline1 = self.campaignLines[1]
                curline2 = self.campaignLines[2]
                count=0
                for i in range(len(self.doc['scenarioParameters'][curline])):
                    for j in range(len(self.doc['scenarioParameters'][curline1])):
                        for k in range(len(self.doc['scenarioParameters'][curline2])):
                            for varParam in self.doc['scenarioParameters'][curCampaign]:
                                sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(count)
                                print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
                                with open('run_%s.sh' % sh_name, 'w') as f:
                                    f.write('#!/bin/bash\n')
                                    f.write('#SBATCH --ntasks=1\n')
                                    f.write('#SBATCH --cpus-per-task='+self.cpusPerTask+'\n')
                                    f.write('#SBATCH --time='+self.daytime+'-'+self.htime+':0 #especifica o tempo máximo de execução do job, dado no padrão dias-horas:minutos\n')
                                    f.write('module load softwares/gsrc/2020_05\n')
                                    outputDir = self.cluster_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
                                    #f.write('rm -rf '+outputDir+"/JOB"+str(iJob)+' 2>/dev/null\n')
                                    #for iJob in range(0, self.nJobs):
                                    f.write('mkdir -p '+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +'\n')
                                    f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
                                    f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
                                    f.write("cd '"+self.cluster_path+"'"+"\n")
                                    command1 = (
                                    'srun -N 1 -n 1' +
                                    " ./waf --cwd='"+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +"'"
                                    " --run '"+self.ns3_script+
                                    " --RngRun="+str(jobRunSeed[iJob]))
                                    command3 =(
                                    " --outputDir='"+outputDir+"/JOB"+str(iJob)+"'"+
                                    " --"+curline+"="+self.doc['scenarioParameters'][curline][i]+
                                    " --"+curline1+"="+self.doc['scenarioParameters'][curline1][j]+
                                    " --"+curline2+"="+self.doc['scenarioParameters'][curline2][k]+
                                    " --"+curCampaign+"="+varParam+
                                    "' > "+outputDir+"/JOB"+str(iJob)+'/Sim_' + str(count)+'.out 2>&1')
                                    f.write(command1+self.commandScript+command3+'\n')
                                    count = count + 1
            
            if nOfCurlines == 2 and SimTied == 1 and nOfCurlinesTied == 2:
                with open('ListOfRandomNumbers.pkl', 'rb') as f:
                    jobRunSeed = pickle.load(f)
                curline = self.campaignLines[0]
                curline1 = self.campaignLines[1]
                #curline=self.doc['scenarioParameters'][campaignLines][0]
                #curline1=self.doc['scenarioParameters'][campaignLines][1]
                count=0
                for i in range(len(self.doc['scenarioParameters'][curline])):
                    for varParam in self.doc['scenarioParameters'][curCampaign]:
                        sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(count)
                        print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
                        with open('run_%s.sh' % sh_name, 'w') as f:
                            f.write('#!/bin/bash\n')
                            f.write('#SBATCH --ntasks=1\n')
                            f.write('#SBATCH --cpus-per-task='+self.cpusPerTask+'\n')
                            f.write('#SBATCH --time='+self.daytime+'-'+self.htime+':0 #especifica o tempo máximo de execução do job, dado no padrão dias-horas:minutos\n')
                            f.write('module load softwares/gsrc/2020_05\n')
                            outputDir = self.cluster_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
                            #f.write('rm -rf '+outputDir+"/JOB"+str(iJob)+' 2>/dev/null\n')
                            #for iJob in range(0, self.nJobs):
                            f.write('mkdir -p '+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +'\n')
                            f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
                            f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
                            f.write("cd '"+self.cluster_path+"'"+"\n")
                            command1 = (
                            'srun -N 1 -n 1' +
                            " ./waf --cwd='"+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +"'"
                            " --run '"+self.ns3_script+
                            " --RngRun="+str(jobRunSeed[iJob]))
                            command3 =(
                            " --outputDir='"+outputDir+"/JOB"+str(iJob)+"'"+
                            " --"+curline+"="+self.doc['scenarioParameters'][curline][i]+
                            " --"+curline1+"="+self.doc['scenarioParameters'][curline1][i]+
                            " --"+curCampaign+"="+varParam+
                            "' > "+outputDir+"/JOB"+str(iJob)+'/Sim_' + str(count)+'.out 2>&1')
                            f.write(command1+self.commandScript+command3+'\n')
                            count = count + 1
            
            if nOfCurlines == 3 and SimTied == 1 and nOfCurlinesTied == 2:
                with open('ListOfRandomNumbers.pkl', 'rb') as f:
                    jobRunSeed = pickle.load(f)
                curline = self.campaignLines[0]
                curline1 = self.campaignLines[1]
                curline2 = self.campaignLines[2]
                count=0
                for i in range(len(self.doc['scenarioParameters'][curline])):
                    for k in range(len(self.doc['scenarioParameters'][curline2])):
                        for varParam in self.doc['scenarioParameters'][curCampaign]:
                            sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(count)
                            print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
                            with open('run_%s.sh' % sh_name, 'w') as f:
                                f.write('#!/bin/bash\n')
                                f.write('#SBATCH --ntasks=1\n')
                                f.write('#SBATCH --cpus-per-task='+self.cpusPerTask+'\n')
                                f.write('#SBATCH --time='+self.daytime+'-'+self.htime+':0 #especifica o tempo máximo de execução do job, dado no padrão dias-horas:minutos\n')
                                f.write('module load softwares/gsrc/2020_05\n')
                                outputDir = self.cluster_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
                                #f.write('rm -rf '+outputDir+"/JOB"+str(iJob)+' 2>/dev/null\n')
                                #for iJob in range(0, self.nJobs):
                                f.write('mkdir -p '+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +'\n')
                                f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
                                f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
                                f.write("cd '"+self.cluster_path+"'"+"\n")
                                command1 = (
                                'srun -N 1 -n 1' +
                                " ./waf --cwd='"+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +"'"
                                " --run '"+self.ns3_script+
                                " --RngRun="+str(jobRunSeed[iJob]))
                                command3 =(
                                " --outputDir='"+outputDir+"/JOB"+str(iJob)+"'"+
                                " --"+curline+"="+self.doc['scenarioParameters'][curline][i]+
                                " --"+curline1+"="+self.doc['scenarioParameters'][curline1][i]+
                                " --"+curline2+"="+self.doc['scenarioParameters'][curline2][k]+
                                " --"+curCampaign+"="+varParam+
                                "' > "+outputDir+"/JOB"+str(iJob)+'/Sim_' + str(count)+'.out 2>&1')
                                f.write(command1+self.commandScript+command3+'\n')
                                count = count + 1
            
            if nOfCurlines == 3 and SimTied == 1 and nOfCurlinesTied == 3:
                with open('ListOfRandomNumbers.pkl', 'rb') as f:
                    jobRunSeed = pickle.load(f)
                curline = self.campaignLines[0]
                curline1 = self.campaignLines[1]
                curline2 = self.campaignLines[2]
                count=0
                for i in range(len(self.doc['scenarioParameters'][curline])):
                    for varParam in self.doc['scenarioParameters'][curCampaign]:
                        sh_name = self.campaign_name + '_' + self.simLocation + '_' + curCampaign + '_JOB' + str(iJob) + '_Sim_' + str(count)
                        print(curCampaign+" campaign written in file: " 'run_%s.sh' % sh_name)
                        with open('run_%s.sh' % sh_name, 'w') as f:
                            f.write('#!/bin/bash\n')
                            f.write('#SBATCH --ntasks=1\n')
                            f.write('#SBATCH --cpus-per-task='+self.cpusPerTask+'\n')
                            f.write('#SBATCH --time='+self.daytime+'-'+self.htime+':0 #especifica o tempo máximo de execução do job, dado no padrão dias-horas:minutos\n')
                            f.write('module load softwares/gsrc/2020_05\n')
                            outputDir = self.cluster_path+'results_'+self.simLocation + '_' + self.campaign_name + '_' + curCampaign
                            #f.write('rm -rf '+outputDir+"/JOB"+str(iJob)+' 2>/dev/null\n')
                            #for iJob in range(0, self.nJobs):
                            f.write('mkdir -p '+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +'\n')
                            f.write('cp -f run_'+sh_name+'.sh'+' '+outputDir+'\n')
                            f.write('cp -f '+self.configurations_file+ ' ' +outputDir+'\n')
                            f.write("cd '"+self.cluster_path+"'"+"\n")
                            command1 = (
                            'srun -N 1 -n 1' +
                            " ./waf --cwd='"+outputDir+"/JOB"+str(iJob)+"/Sim_"+str(count) +"'"
                            " --run '"+self.ns3_script+
                            " --RngRun="+str(jobRunSeed[iJob]))
                            command3 =(
                            " --outputDir='"+outputDir+"/JOB"+str(iJob)+"'"+
                            " --"+curline+"="+self.doc['scenarioParameters'][curline][i]+
                            " --"+curline1+"="+self.doc['scenarioParameters'][curline1][i]+
                            " --"+curline2+"="+self.doc['scenarioParameters'][curline2][i]+
                            " --"+curCampaign+"="+varParam+
                            "' > "+outputDir+"/JOB"+str(iJob)+'/Sim_' + str(count)+'.out 2>&1')
                            f.write(command1+self.commandScript+command3+'\n')
                            count = count + 1
            
                                                

parser = argparse.ArgumentParser()
parser.add_argument("-f", "--file", type=str, help='Configuration File')
args = parser.parse_args()

configurations_file = args.file; 
with open(configurations_file, 'r') as f:
    doc = yaml.load(f, Loader=yaml.loader.BaseLoader)
    campaign_name = os.path.splitext(configurations_file)[0]
"""
doc = {'ns3Parameters': {'ns3_path': '',
  'ns3_script': 'NrMmtc-M1_v3',
  'cluster_path': '/home/drdluna/5G-LENA/ns-3-dev-nr-1.2-wpatch-epsbearer/',
  'filename': 'CampaignNrCa',
  'simLocation': 'cluster'},
 'ShellScriptParameters': {'nOfCurlines': '3',
  'SimTied': '0',
  'nOfCurlinesTied': '2',
  'daytime': '1',
  'htime': '12',
  'ntasks': '16',
  'cpusPerTask': '16',
  'numberOfJobsShellScript': '5'},
 'campaignLines': {'campaignX': ['Lambda'],
  'campaignLines': ['BwpConfiguration', 'BwpBand', 'totalTxPower'],
  'jobs': '20'},
 'scenarioParameters': {'window': ['0.1'],
  'simTime': ['90'],
  'Isd': ['500'],
  'ueNumScenario': ['84'],
  'centralFrequencyBand': ['2350000000'],
  'bandwidthBand': ['100000000'],
  'BwpConfiguration': ['1', '2', '3', '4'],
  'BwpBand': ['72000000', '36000000', '24000000', '18000000'],
  'remBwpId': ['0'],
  'scenario': ['UmaLos'],
  'Shadowing': ['0'],
  'ChannelUpdate': ['0'],
  'totalTxPower': ['26', '23'],
  'totalUePower': ['23'],
  'DowntiltAngleDegree': ['0'],
  'BearingAngleTilt': ['-30'],
  'UlMode': ['1'],
  'TrafficModel': ['TriggeredReport'],
  'numerology': ['0'],
  'PacketSize': ['125'],
  'interval': ['60'],
  'Lambda': ['0.1', '0.5', '1', '2']}}

configurations_file = "NrMmtc_SimPerScriptCampaign_SimTeste.yaml"
"""
print('Simulação escolhida: ')
campaign = doc['campaignLines']['campaignX']
print(campaign)
                 
simu = Simulation(configurations_file)

for simC in campaign:
    simu.runCampaign(simC)
# Out:
# Writing NrMmtcSimPerScriptCampaign.py

# %% [markdown]
# # Campanhas em TDD

# %%
# %cd $path
# !mkdir "SimTeste"
# %cp -f "NrMmtc_SimPerScriptCampaign.py" $path"/SimTeste"
# %cp -f "ListOfRandomNumbers.pkl" $path"/SimTeste"
# %cd "SimTeste"
# Out:
# /home/daniel/Daniel/ScriptsCampaign
# mkdir: cannot create directory ‘SimTeste’: File exists
# cp: cannot stat 'NrMmtc_SimPerScriptCampaign.py': No such file or directory
# /home/daniel/Daniel/ScriptsCampaign/SimTeste

# %%
# %%file NrMmtc_SimPerScriptCampaign_SimTeste.yaml
# # ns-3 script configuration
# ns3Parameters:
#
#     ns3_path:                       # Complete path of ns-3 simulator - NOT USED
#     ns3_script: NrMmtc-M1_v3   # Script with the main code (inside scratch folder without .cc)
#     cluster_path: /home/drdluna/5G-LENA/ns-3-dev-nr-1.2-wpatch-epsbearer/
#     filename: CampaignNrCa          # Output filename - NOT USED
#     simLocation: cluster            # Set location of simulation (local or cluster) - ONLY supports "cluster"
#
# # Shell Script Parameters configuration
# ShellScriptParameters:
#
#     nOfCurlines: 3     # number of Campaign Lines
#     SimTied: 1           # whether or not campaign lines are tied
#     nOfCurlinesTied: 2  # n.o Campaign Lines Tied
#     daytime: 1          # number of days to simulate (only for cluster simulation)
#     htime: 12            # number of hours to simulate (only for cluster simulation)
#     ntasks: 32           # number of simulation in one .sh (only for cluster simulation - default: 30)
#     cpusPerTask: 16      # numer of CPUs per Task
#     numberOfJobsShellScript: 5
#
# #Lines/curves
# campaignLines:
#
#     campaignX:          # campaignX: parameter name to vary in the X-axis (ONLY 1)
#         - Lambda
#     campaignLines:      # campaignLines: parameter name to vary in different lines
#         - BwpConfiguration
#         - BwpBand
#         - totalTxPower
#     jobs: 20             # Number of jobs to run
#
# # Simu parameters. It is also necessary to create an "outputDir" parameter in your ns-3 script.
# # outputDir will be constructed based on cluster_path, therefore it is not necessary declare it below.
# scenarioParameters:
#     window:
#         - 0.1
#     simTime:            # Simulation duration (seconds)
#         - 90
#     Isd:
#         - 500
#     ueNumScenario:
#         - 84
#     centralFrequencyBand:
#         - 2350000000
#     bandwidthBand:
#         - 100000000
#     BwpConfiguration:
#         - 1
#         - 2
#         - 3
#         - 4
#     BwpBand:
#         - 72000000
#         - 36000000
#         - 24000000
#         - 18000000
#     remBwpId:
#         - 0
#     scenario:
#         - UmaLos
#     Shadowing:
#         - 0
#     ChannelUpdate:
#         - 0
#     totalTxPower:
#         - 26
#         - 23
#     totalUePower:
#         - 23
#     DowntiltAngleDegree:
#         - 0
#     BearingAngleTilt:
#         - -30
#     UlMode:
#         - 1
#     TrafficModel:
#         - TriggeredReport
#     numerology:
#         - 0
#     PacketSize:
#         - 125
#     interval:
#         - 60
#     Lambda:
#         - 0.1
#         - 0.5
#         - 1
#         - 2
# Out:
# Overwriting NrMmtc_SimPerScriptCampaign_SimTeste.yaml

# %%
# %run NrMmtc_SimPerScriptCampaign -f "NrMmtc_SimPerScriptCampaign_SimTeste.yaml"
# Out:
# Simulação escolhida:
# ['Lambda']
# Main Shell Script: NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_AllJOBS0.sh
# Main Shell Script: NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_AllJOBS1.sh
# Main Shell Script: NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_AllJOBS2.sh
# Main Shell Script: NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_AllJOBS3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB0_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB1_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB2_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB3_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB4_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB5_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB6_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB7_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB8_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB9_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB10_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB11_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB12_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB13_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB14_Sim_9.sh
# ...
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB15_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB16_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB17_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB18_Sim_31.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_0.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_1.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_2.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_3.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_4.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_5.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_6.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_7.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_8.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_9.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_10.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_11.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_12.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_13.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_14.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_15.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_16.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_17.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_18.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_19.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_20.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_21.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_22.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_23.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_24.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_25.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_26.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_27.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_28.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_29.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_30.sh
# Lambda campaign written in file: run_NrMmtc_SimPerScriptCampaign_SimTeste_cluster_Lambda_JOB19_Sim_31.sh
